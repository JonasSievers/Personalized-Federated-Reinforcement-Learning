# %%
import pandas as pd
import numpy as np
from utils.EnergyDataset import EnergyDataset

# %%
ds = EnergyDataset(data_path='../data/Final_Energy_dataset.csv', mode='test')

# %%
ds.getAll()['price'].plot()
# Out:
# <Axes: >
